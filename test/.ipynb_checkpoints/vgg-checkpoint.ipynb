# %%
import torchvision.models as models
import torch

vgg16 = models.vgg16().cuda()

# %%
vgg16(torch.rand(1,3,224,224).cuda()).shape
# Out:
# torch.Size([1, 1000])

# %%
sum(param.numel() for param in vgg16.parameters())
# Out:
# 138357544

# %%
torch.rand(2,4,321,481)
# Out:
# tensor([[[[3.7662e-01, 1.7516e-01, 4.8327e-01,  ..., 3.6995e-01,
#            1.3926e-01, 4.3721e-02],
#           [4.4061e-01, 3.4502e-01, 6.8196e-01,  ..., 9.7959e-01,
#            4.3520e-01, 2.2756e-01],
#           [4.3940e-01, 6.4954e-01, 1.6085e-01,  ..., 2.0179e-01,
#            4.3832e-01, 1.7404e-01],
#           ...,
#           [4.7818e-01, 4.8783e-01, 5.8807e-01,  ..., 5.5735e-02,
#            9.5490e-02, 9.0493e-02],
#           [7.0569e-01, 4.1027e-01, 2.4287e-03,  ..., 5.3990e-02,
#            1.9676e-01, 4.1005e-01],
#           [6.1634e-01, 5.4050e-01, 4.3187e-01,  ..., 3.4618e-01,
#            9.3769e-01, 3.6657e-01]],
#
#          [[3.9928e-01, 3.3017e-01, 7.8665e-01,  ..., 3.8752e-02,
#            7.8876e-01, 1.3354e-01],
#           [6.0189e-01, 8.2704e-01, 7.6014e-01,  ..., 4.4189e-01,
#            7.3219e-01, 9.6366e-01],
#           [1.1177e-01, 9.0009e-01, 7.4514e-01,  ..., 1.1699e-01,
#            7.3623e-02, 9.1936e-01],
#           ...,
# ...

# %%
from network import *

# %%
model = PixelAffinityNet(nr_channel=128, conv1_size=7, use_canny=True).cuda()
# Out:
# use_canny = True

# %%
model(torch.rand(1,4,321,481).cuda())
# Out:
# tensor([[[[0.7409, 0.7336, 0.2561,  ..., 0.7418, 0.0489, 0.7888],
#           [0.3768, 0.7346, 0.1464,  ..., 0.6384, 0.6765, 0.3122],
#           [0.1515, 0.5569, 0.1151,  ..., 0.2002, 0.5213, 0.4515],
#           ...,
#           [0.4078, 0.3605, 0.6362,  ..., 0.8019, 0.1902, 0.7015],
#           [0.6251, 0.6596, 0.6547,  ..., 0.6257, 0.6794, 0.1878],
#           [0.6633, 0.5645, 0.6216,  ..., 0.7287, 0.7534, 0.7631]]],
#
#
#         [[[0.6671, 0.7632, 0.1012,  ..., 0.6469, 0.4761, 0.6496],
#           [0.2549, 0.3264, 0.6430,  ..., 0.7259, 0.0962, 0.4187],
#           [0.0633, 0.5372, 0.6217,  ..., 0.4994, 0.7508, 0.6205],
#           ...,
#           [0.0920, 0.7674, 0.7646,  ..., 0.6827, 0.1141, 0.7578],
#           [0.2045, 0.5659, 0.7351,  ..., 0.5665, 0.3474, 0.7487],
#           [0.7356, 0.1324, 0.4407,  ..., 0.7268, 0.2645, 0.6183]]],
#
#
#         [[[0.6980, 0.7103, 0.6365,  ..., 0.7280, 0.4348, 0.1080],
#           [0.1623, 0.2536, 0.6321,  ..., 0.3349, 0.0844, 0.6933],
# ...
